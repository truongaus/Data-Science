# %% [markdown]
# # Chapter 3 - Exercise 1: Lọc và sắp xếp dữ liệu UEFA_European_Championship/Euro 2012
# Bộ dữ liệu này liên quan đến giải vô địch bóng đá châu Âu Euro 2012, bao gồm thông tin về các trận đấu, đội bóng, cầu thủ, kết quả, và nhiều yếu tố thống kê khác liên quan đến giải đấu Euro 2012.

# %% [markdown]
# #### Lấy dữ liệu từ đường dẫn
# [Euro 12](https://raw.githubusercontent.com/jokecamp/FootballData/master/UEFA_European_Championship/Euro%202012/Euro%202012%20stats%20TEAM.csv) hoặc tập tin "euro2012.csv" cho sẵn trong thư mục data.
#
# Dữ liệu bao gồm 16 quốc gia, với các cột như sau:
# - **Team**: tên đội bóng
# - **Goals**: Số bàn thắng đã ghi
# - **Shots on target**: Số lần sút mà thực sự bị thủ môn đối phương cản phá
# - **Shots off target**: Số lần sút không trúng khung thành đối phương
# - **Shooting Accuracy**: Tỷ lệ phần trăm giữa số lần sút trúng mục tiêu và tổng số lần sút. Đây là một chỉ số quan trọng để đánh giá độ chính xác của việc sút của đội bóng.
# - **% Goals-to-shots**: Tỷ lệ phần trăm giữa số bàn thắng và tổng số lần sút.
# - **Total shots (inc. Blocked)**: Tổng số lần sút của đội bóng, bao gồm cả những lần sút bị chặn.
# - **Hit Woodwork**: Số lần bóng của đội bóng đập vào khung gỗ mà không ghi bàn.
# - **Penalty goals**: Số bàn thắng được ghi từ quả penalty.
# - **Penalties not scored**: Số lần đá penalty nhưng không ghi bàn.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Bước 1: Đọc dữ liệu

# %%
# Đọc dữ liệu từ tập tin euro2012.csv vào dataframe euro12
euro12 = pd.read_csv('euro2012.csv',index_col=0)
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Bước 2: Khám phá dữ liệu

# %%
# Hiển thị thông tin info
euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  16 non-null     int64
#  1   Team                        16 non-null     object
#  2   Goals                       16 non-null     int64
#  3   Shots on target             16 non-null     int64
#  4   Shots off target            16 non-null     int64
#  5   Shooting Accuracy           16 non-null     object
#  6   % Goals-to-shots            16 non-null     object
#  7   Total shots (inc. Blocked)  16 non-null     int64
#  8   Hit Woodwork                16 non-null     int64
#  9   Penalty goals               16 non-null     int64
#  10  Penalties not scored        16 non-null     int64
#  11  Headed goals                16 non-null     int64
#  12  Passes                      16 non-null     int64
# ...

# %%
# Xem thống kê mô tả về dữ liệu
euro12.describe()
# Out:
#            Goals  Shots on target  Shots off target  Shooting Accuracy  \
# count  16.000000        16.000000         16.000000          16.000000
# mean    4.750000        17.125000         24.937500          39.718750
# std     2.886751        10.582218         10.680005          10.761426
# min     1.000000         7.000000         10.000000          21.200000
# 25%     2.750000         9.750000         18.000000          33.400000
# 50%     4.500000        13.000000         23.500000          40.650000
# 75%     5.250000        22.000000         32.250000          48.350000
# max    12.000000        42.000000         45.000000          55.900000
#
#        Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# count                   16.000000     16.000000      16.000000
# mean                    54.937500      1.250000       0.187500
# std                     26.065223      1.612452       0.403113
# min                     27.000000      0.000000       0.000000
# ...

# %%
# Cho biết các cột dữ liệu
euro12.dtypes
# Out:
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy             float64
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# Blocks                          int64
# Goals conceded                  int64
# ...

# %%
# Có bao nhiêu đội tham gia Euro2012?
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# ### Bước 3: Chuyển đổi kiểu dữ liệu

# %%
# Hiển thị 5 dòng đầu tiên của các cột 'Shooting Accuracy', '% Goals-to-shots', 'Passing Accuracy', 'Saves-to-shots ratio'

# %%
# Nhận xét về kiểu dữ liệu của các cột này

# %% [markdown]
# Các cột dữ liệu này được mong đợi ở kiểu dữ liệu float, tuy nhiên chúng đang ở kiểu object. (có dấu % ở sau giá trị)

# %% [markdown]
# ### Bước 4: Sắp xếp dữ liệu

# %%
# Cho biết 5 đội có ghi được nhiều bàn thắng nhất

# %%
# Cho biết đội bóng nhận nhiều thẻ vàng nhất

# %%
# In ra đội có Shooting Accuracy cao nhất

# %%
# Sắp xếp theo cột "Goals" giảm dần

# %%
# Tạo 1 data frame mới từ euro12 có tên là discipline (kỷ luật) chỉ chứa 3 cột 'Team', 'Yellow Cards', 'Red Cards'

# %%
# Sắp xếp discipline giảm dần theo 2 cột 'Red Cards', 'Yellow Cards'

# %% [markdown]
# ### Bước 5: Truy xuất dữ liệu

# %%
# Lọc các đội đã ghi 10 bàn thắng trở lên
euro12.loc[euro12.Goals>10]
# Out:
#      Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 13  Spain     12               42                33               55.9
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 13             83        19            11          0       17        17
#
#     Players Used
# 13            18
#
# [1 rows x 35 columns]

# %%
# In ra các đội có Goals > 6 và có thẻ vàng
euro12.loc[(euro12.Goals>6) & (euro12['Yellow Cards']>0)]
# Out:
#        Team  Goals  Shots on target  Shots off target  Shooting Accuracy  \
# 5   Germany     10               32                32               47.8
# 13    Spain     12               42                33               55.9
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# In các đội mà tên bắt đầu bằng 'G' (gợi ý: dùng str.startswith())
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# In các cột 'Team','Shooting Accuracy' từ 'England', 'Italy', 'Russia'
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team  Shooting Accuracy
# 3   England               50.0
# 7     Italy               43.0
# 12   Russia               22.5

# %%
# In các đội có cột Shooting Accuracy >= 50.0%

# %% [markdown]
# ### Bước 6: Tính toán thêm thông tin dựa trên các cột hiện có

# %%
# Tính trung bình 'Goals' trên 'Shots on target'

# %%
# Tính tổng số lần đá phạt góc của tất cả đội

# %%
# Tính tỷ lệ số bàn thắng trung bình trên số lần đá phạt góc

# %% [markdown]
# ### Bước 7: Trực quan hóa dữ liệu

# %%
# Trực quan số lần (Shots on target) của mỗi đội bóng

# %%
# Trực quan số thẻ vàng (Yellow Cards) và số thẻ đỏ (Red Cards) của mỗi đội bóng
